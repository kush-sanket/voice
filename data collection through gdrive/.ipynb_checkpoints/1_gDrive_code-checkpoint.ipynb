# %%
import os
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive

gauth = GoogleAuth()
drive = GoogleDrive(gauth)

# %%
folder = '10ExxCK4uHgYduJFCMrb1xuEadtv87CIxVP-jXfBEXq6C34msw3iVI4Oxb4zr3HpEYF6HbT9O'

# %%
#folder = '1Ob1hXef5fzYqiHkenuEf-QgGtp2AsmsN'

# %%
# Download files
file_list = drive.ListFile({'q' : f"'{folder}' in parents and trashed=false"}).GetList()
print(file_list)
for index, file in enumerate(file_list):
    print(index+1, 'file downloaded : ', file['title'])
    file.GetContentFile(file['title'])
# Out:
# Your browser has been opened to visit:
#
#     https://accounts.google.com/o/oauth2/auth?client_id=615839328458-j689gi3aqq1pbsv717n6623amjjeqnf7.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8080%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&access_type=offline&response_type=code
#
# Authentication successful.
# [GoogleDriveFile({'kind': 'drive#file', 'id': '1jD52l-Yh7YQIHmZuKqd6s9KNHnDFa9cI', 'etag': '"MTY0NzU4ODQ2NzYyNg"', 'selfLink': 'https://www.googleapis.com/drive/v2/files/1jD52l-Yh7YQIHmZuKqd6s9KNHnDFa9cI', 'webContentLink': 'https://drive.google.com/uc?id=1jD52l-Yh7YQIHmZuKqd6s9KNHnDFa9cI&export=download', 'alternateLink': 'https://drive.google.com/file/d/1jD52l-Yh7YQIHmZuKqd6s9KNHnDFa9cI/view?usp=drivesdk', 'embedLink': 'https://drive.google.com/file/d/1jD52l-Yh7YQIHmZuKqd6s9KNHnDFa9cI/preview?usp=drivesdk', 'iconLink': 'https://drive-thirdparty.googleusercontent.com/16/type/audio/mpeg', 'title': 'my name is Swagata Adhya - Swagata Adhya.mp3', 'mimeType': 'audio/mpeg', 'labels': {'starred': False, 'hidden': False, 'trashed': False, 'restricted': False, 'viewed': True}, 'copyRequiresWriterPermission': False, 'createdDate': '2021-12-18T17:38:36.794Z', 'modifiedDate': '2022-03-18T07:27:47.626Z', 'lastViewedByMeDate': '2022-05-04T17:24:33.903Z', 'markedViewedByMeDate': '1970-01-01T00:00:00.000Z', 'sharedWithMeDate': '2022-03-18T07:27:47.772Z', 'version': '14', 'sharingUser': {'kind': 'drive#user', 'displayName': 'Sanket Kushwaha', 'picture': {'url': 'https://lh3.googleusercontent.com/a/default-user=s64'}, 'isAuthenticatedUser': False, 'permissionId': '00462602848914511311', 'emailAddress': 'saku20mca@cmrit.ac.in'}, 'parents': [{'kind': 'drive#parentReference', 'id': '10ExxCK4uHgYduJFCMrb1xuEadtv87CIxVP-jXfBEXq6C34msw3iVI4Oxb4zr3HpEYF6HbT9O', 'selfLink': 'https://www.googleapis.com/drive/v2/files/1jD52l-Yh7YQIHmZuKqd6s9KNHnDFa9cI/parents/10ExxCK4uHgYduJFCMrb1xuEadtv87CIxVP-jXfBEXq6C34msw3iVI4Oxb4zr3HpEYF6HbT9O', 'parentLink': 'https://www.googleapis.com/drive/v2/files/10ExxCK4uHgYduJFCMrb1xuEadtv87CIxVP-jXfBEXq6C34msw3iVI4Oxb4zr3HpEYF6HbT9O', 'isRoot': False}], 'downloadUrl': 'https://www.googleapis.com/drive/v2/files/1jD52l-Yh7YQIHmZuKqd6s9KNHnDFa9cI?alt=media&source=downloadUrl', 'userPermission': {'kind': 'drive#permission', 'etag': '"VEkWoTDeZuK5I5e_WPXWI-oR_es"', 'id': 'me', 'selfLink': 'https://www.googleapis.com/drive/v2/files/1jD52l-Yh7YQIHmZuKqd6s9KNHnDFa9cI/permissions/me', 'role': 'writer', 'type': 'user', 'pendingOwner': False}, 'originalFilename': 'my name is Swagata Adhya - Swagata Adhya.mp3', 'fileExtension': 'mp3', 'md5Checksum': '396fbe972da688e30aeeaa51e2435c71', 'fileSize': '108623', 'quotaBytesUsed': '108623', 'ownerNames': ['Sanket Kushwaha'], 'owners': [{'kind': 'drive#user', 'displayName': 'Sanket Kushwaha', 'picture': {'url': 'https://lh3.googleusercontent.com/a/default-user=s64'}, 'isAuthenticatedUser': False, 'permissionId': '00462602848914511311', 'emailAddress': 'saku20mca@cmrit.ac.in'}], 'lastModifyingUserName': 'Sanket Kushwaha', 'lastModifyingUser': {'kind': 'drive#user', 'displayName': 'Sanket Kushwaha', 'picture': {'url': 'https://lh3.googleusercontent.com/a/default-user=s64'}, 'isAuthenticatedUser': False, 'permissionId': '00462602848914511311', 'emailAddress': 'saku20mca@cmrit.ac.in'}, 'capabilities': {'canCopy': True, 'canEdit': True}, 'editable': True, 'copyable': True, 'writersCanShare': True, 'shared': True, 'explicitlyTrashed': False, 'appDataContents': False, 'headRevisionId': '0BwaLg-Yc-8trT21DREtsSjFrRjl4TUQ5VXhXVzVQcFJtSzBzPQ', 'spaces': ['drive']}), GoogleDriveFile({'kind': 'drive#file', 'id': '1Ob1hXef5fzYqiHkenuEf-QgGtp2AsmsN', 'etag': '"MTY0NzQyMDU5MjY4Mw"', 'selfLink': 'https://www.googleapis.com/drive/v2/files/1Ob1hXef5fzYqiHkenuEf-QgGtp2AsmsN', 'webContentLink': 'https://drive.google.com/uc?id=1Ob1hXef5fzYqiHkenuEf-QgGtp2AsmsN&export=download', 'alternateLink': 'https://drive.google.com/file/d/1Ob1hXef5fzYqiHkenuEf-QgGtp2AsmsN/view?usp=drivesdk', 'embedLink': 'https://drive.google.com/file/d/1Ob1hXef5fzYqiHkenuEf-QgGtp2AsmsN/preview?usp=drivesdk', 'iconLink': 'https://drive-thirdparty.googleusercontent.com/16/type/audio/aac', 'title': 'Record-002 - SUBHAM KUMAR.aac', 'mimeType': 'audio/aac', 'labels': {'starred': False, 'hidden': False, 'trashed': False, 'restricted': False, 'view ...
# 1 file downloaded :  my name is Swagata Adhya - Swagata Adhya.mp3
# 2 file downloaded :  Record-002 - SUBHAM KUMAR.aac
# 3 file downloaded :  27 Dec, 10.14 am​ - RAVURI LAKSHMI PRIYA.aac
# 4 file downloaded :  Name recording - NAVEEN T.aac
# 5 file downloaded :  24 Dec, 8.01 pm​ - Prachi Khandke.aac
# 6 file downloaded :  AUDIO-2021-12-24-17-38-31 - Aditi Dhamanekar.m4a
# 7 file downloaded :  Anuhya  - KANKANALA ANUHYA
# 8 file downloaded :  24 Dec, 6.28 pm​ - DEEPANKAR BAIDYA.aac
# 9 file downloaded :  Abhishek - Abhishek Pandey.mp3
# 10 file downloaded :  voice - Pavitra Kirthi B.ogg
# 11 file downloaded :  718782 - PRAMODA ND
# 12 file downloaded :  24 Dec, 17.20​ - M PAVAN.aac
# 13 file downloaded :  survey audio - SREE VAISHNAVI R N.mp3
# 14 file downloaded :  Standard recording 1 - Abhishek Kumar.mp3
# 15 file downloaded :  24 Dec, 3.45 pm​ - CHETHAN KUMAR N.aac
# 16 file downloaded :  24 Dec, 3.36 pm - ASHURAM AGNIHOTRI.mp3

# %%
file_list = drive.ListFile({'q': f"'{folder}' in parents"}).GetList()
for file1 in file_list:
    print('title: {}, id: {}'.format(file1['title'], file1['id']))
    
    
    #input men id o/p title
# Out:
# title: my name is Swagata Adhya - Swagata Adhya.mp3, id: 1jD52l-Yh7YQIHmZuKqd6s9KNHnDFa9cI
# title: Record-002 - SUBHAM KUMAR.aac, id: 1Ob1hXef5fzYqiHkenuEf-QgGtp2AsmsN
# title: 27 Dec, 10.14 am​ - RAVURI LAKSHMI PRIYA.aac, id: 1dbyG3awUP3lp2I3W0UptJdktV8aH0a0d
# title: Name recording - NAVEEN T.aac, id: 1IP1NU_zv1-zKwknLt8tUKegAx4BPm1iH
# title: 24 Dec, 8.01 pm​ - Prachi Khandke.aac, id: 10x-wioXAS9BhPt35eAJG4Olm61hPUbUs
# title: AUDIO-2021-12-24-17-38-31 - Aditi Dhamanekar.m4a, id: 1S1EnFy6ufG_ZZh8hZsk3Ug6hsEYTpzRy
# title: Anuhya  - KANKANALA ANUHYA, id: 1YwLfgRnKJcANFge1ZtOOKCBFA-Ewe5W2
# title: 24 Dec, 6.28 pm​ - DEEPANKAR BAIDYA.aac, id: 1nVOvxMaKyV_4WifIMwgZJg_39qOVWbE1
# title: Abhishek - Abhishek Pandey.mp3, id: 1IPyI6omD-tkxJV6SzkdLgfnf5UZlf9tg
# title: voice - Pavitra Kirthi B.ogg, id: 1B6hKxA2l18Gu8LjM-J5IRj4MlmFLKuJR
# title: 718782 - PRAMODA ND, id: 1PTSybMmNFWIquiNUtSvLAEGvEnf0z0UX
# title: 24 Dec, 17.20​ - M PAVAN.aac, id: 17f-XSW7TXvukmPiYF5d7ZlKkXGGZFn_T
# title: survey audio - SREE VAISHNAVI R N.mp3, id: 1j0VulaA1iA2NXP3EpWhUeWk-7r8gY05I
# title: Standard recording 1 - Abhishek Kumar.mp3, id: 1iVV7vIt9GVdqPGBuWlR4sIBB0rMS1VFC
# title: 24 Dec, 3.45 pm​ - CHETHAN KUMAR N.aac, id: 17EKScdgZYVWVRDvWZxpGRFmc6ZZrS5Lz
# title: 24 Dec, 3.36 pm - ASHURAM AGNIHOTRI.mp3, id: 1bKKFaGPz5mZ_Wt2p0ymj8zEVV0p4LOJ2
# title: 24 Dec, 15.36​ - G PAVAN KUMAR.aac, id: 17PzWuj0PReWLWnso0ZQuZadtb1wCky3L
# title: 24 Dec, 3.30 pm​ - Sanket Kushwaha.aac, id: 1ywRmcf6TjjAAtS1kxSGHFGsECHB7QV9k
# title: 24 Dec, 3.26 pm​ - MONIKA CP.aac, id: 1jfc-KUTOV1XdW6eUb5mmOR209LJk8aca
# title: name - BODIMALLA BALAJI REDDY.m4a, id: 1Rq9ya4S9EFvlWGmLFgbViRPiaiAyU9Vz
# title: New recording 3 - LIPSA RANI BIHARI.m4a, id: 15h_KbafXfJ_VdCHMnJXur1Yy_KJv7iXK
# title: 415992 - CHIRLAM CHARLA MANJUNATH, id: 1L8_-6PC9oUqeIXHOPYNA3dYdyBcNmRl8
# title: Mahendar - MAHENDAR KUMAR S, id: 1dsxS_cgUf5K7RZyUV9IoOqdHd_mSx5yM
# title: 24 Dec, 3.20 pm​ - ARYAN RAJ.aac, id: 10Y7Pbp1M-AREmK5OIQmtzQlslvbEqQTd
# title: 485307 - SANDEEP H, id: 14jw_IIc9xJ2JvrUXtEJlibE9Pa1gqDM6
# title: Ashwani Kumar voice - Ashwani kumar.m4a, id: 1N1TZRpgdFkN7CDIYAuzIFSm7FimjoQRm
# title: IMG_0600 - Ravindra kumar Singh.MOV, id: 1b2O6vq9nlAan9E-Yn6ZErm9XNBtcrJXP
# title: siddharth - Siddharth madala.aac, id: 1VZ6vZgrJ6z605VIbAGVFcxCGMhzA8RdS
# title: mamta devi - Rudra Prakash, id: 1tUpkUfmxdWX3OBIvJ1IsXLmo0a1dYtXt
# title: Voice 002 - sanchit kushwaha.m4a, id: 1zP-eKVCQrlM70we9Tw8VQypU6gshxM8R

# %%
file5 = drive.CreateFile()
file6 = drive.CreateFile({'id': '1jD52l-Yh7YQIHmZuKqd6s9KNHnDFa9cI'})
file6.GetContentFile('my name is Swagata Adhya - Swagata Adhya.mp3') # Download file as 'catlove.png'.
# Out:
# Your browser has been opened to visit:
#
#     https://accounts.google.com/o/oauth2/auth?client_id=615839328458-j689gi3aqq1pbsv717n6623amjjeqnf7.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8080%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&access_type=offline&response_type=code
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\httplib2\__init__.py in _conn_request(self, conn, request_uri, method, body, headers)
#    1342                 if conn.sock is None:
# -> 1343                     conn.connect()
#    1344                 conn.request(method, request_uri, body, headers)
#
# ~\anaconda3\lib\site-packages\httplib2\__init__.py in connect(self)
#    1118
# -> 1119         address_info = socket.getaddrinfo(host, port, 0, socket.SOCK_STREAM)
#    1120         for family, socktype, proto, canonname, sockaddr in address_info:
#
# ~\anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     917     addrlist = []
# --> 918     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     919         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# ServerNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-c9cb11a8403f> in <module>
#       1 file5 = drive.CreateFile()
#       2 file6 = drive.CreateFile({'id': '1jD52l-Yh7YQIHmZuKqd6s9KNHnDFa9cI'})
# ----> 3 file6.GetContentFile('my name is Swagata Adhya - Swagata Adhya.mp3') # Download file as 'catlove.png'.
#
# ~\anaconda3\lib\site-packages\pydrive\files.py in GetContentFile(self, filename, mimetype, remove_bom)
#     208                     type(self.content) is not io.BytesIO or \
#     209                     self.has_bom == remove_bom:
# --> 210       self.FetchContent(mimetype, remove_bom)
#     211     f = open(filename, 'wb')
#     212     f.write(self.content.getvalue())
#
# ~\anaconda3\lib\site-packages\pydrive\files.py in _decorated(self, *args, **kwargs)
#      40   def _decorated(self, *args, **kwargs):
#      41     if not self.uploaded:
# ---> 42       self.FetchMetadata()
#      43     return decoratee(self, *args, **kwargs)
#      44   return _decorated
#
# ~\anaconda3\lib\site-packages\pydrive\auth.py in _decorated(self, *args, **kwargs)
#      55         self.auth.ServiceAuth()
#      56       else:
# ---> 57         self.auth.LocalWebserverAuth()
#      58
#      59     # Initialise service if not built yet.
#
# ~\anaconda3\lib\site-packages\pydrive\auth.py in _decorated(self, *args, **kwargs)
#     123         dirty = True
#     124     if code is not None:
# --> 125       self.Auth(code)
#     126     if dirty and save_credentials:
#     127       self.SaveCredentials()
#
# ~\anaconda3\lib\site-packages\pydrive\auth.py in Auth(self, code)
#     493     :raises: AuthenticationError
#     494     """
# --> 495     self.Authenticate(code)
#     496     self.Authorize()
#     497
#
# ~\anaconda3\lib\site-packages\pydrive\auth.py in Authenticate(self, code)
#     506       self.GetFlow()
#     507     try:
# --> 508       self.credentials = self.flow.step2_exchange(code)
#     509     except FlowExchangeError as e:
#     510       raise AuthenticationError('OAuth2 code exchange failed: %s' % e)
#
# ~\anaconda3\lib\site-packages\oauth2client\_helpers.py in positional_wrapper(*args, **kwargs)
#     131                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     132                     logger.warning(message)
# --> 133             return wrapped(*args, **kwargs)
#     134         return positional_wrapper
#     135
#
# ~\anaconda3\lib\site-packages\oauth2client\client.py in step2_exchange(self, code, http, device_flow_info)
#    2051             http = transport.get_http_object()
#    2052
# -> 2053         resp, content = transport.request(
#    2054             http, self.token_uri, method='POST', body=body, headers=headers)
#    2055         d = _parse_exchange_token_response(content)
#
# ~\anaconda3\lib\site-packages\oauth2client\transport.py in request(http, uri, method, body, headers, redirections, connection_type)
#     278     # NOTE: Allowing http or http.request is temporary (See Issue 601).
#     279     http_callable = getattr(http, 'request', http)
# --> 280     return http_callable(uri, method=method, body=body, headers=headers,
#     281                          redirections=redirections,
#     282                          connection_type=connection_type)
#
# ~\anaconda3\lib\site-packages\httplib2\__init__.py in request(self, uri, method, body, headers, redirections, connection_type)
#    1699                     content = b""
#    1700                 else:
# -> 1701                     (response, content) = self._request(
#    1702                         conn, authority, uri, request_uri, method, body, headers, redirections, cachekey,
#    1703                     )
#
# ~\anaconda3\lib\site-packages\httplib2\__init__.py in _request(self, conn, host, absolute_uri, request_uri, method, body, headers, redirections, cachekey)
#    1419             auth.request(method, request_uri, headers, body)
#    1420
# -> 1421         (response, content) = self._conn_request(conn, request_uri, method, body, headers)
#    1422
#    1423         if auth:
#
# ~\anaconda3\lib\site-packages\httplib2\__init__.py in _conn_request(self, conn, request_uri, method, body, headers)
#    1348             except socket.gaierror:
#    1349                 conn.close()
# -> 1350                 raise ServerNotFoundError("Unable to find the server at %s" % conn.host)
#    1351             except socket.error as e:
#    1352                 errno_ = _errno_from_exception(e)
#
# ServerNotFoundError: Unable to find the server at oauth2.googleapis.com
